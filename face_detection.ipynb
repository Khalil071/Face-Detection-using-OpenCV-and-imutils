# %%
pip install opencv-python

# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image_path = "/content/drive/My Drive/computing_vision/computer_vision/openCV/people.jpg"

# %%
image = cv2.imread(image_path)

# %%
image.shape
# Out:
# (408, 612, 3)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image.shape
# Out:
# (408, 612)

# %%
face_classifier = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %%
face = face_classifier.detectMultiScale(
    gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30)
)

face
# Out:
# array([[309,  97,  52,  52]], dtype=int32)

# %%
for (x, y, w, h) in face:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=612x408>

# %%
myimage_path = "/content/drive/My Drive/computing_vision/computer_vision/openCV/friends.jpg"

# %%
import os
print(os.path.exists(myimage_path))
# Out:
# True

# %%
myimage = cv2.imread(myimage_path)
myimage.shape
# Out:
# (198, 246, 3)

# %%
myimage_gray = cv2.cvtColor(myimage, cv2.COLOR_BGR2GRAY)
myimage_gray.shape
# Out:
# (198, 246)

# %%
myimage_face = face_classifier.detectMultiScale(
    myimage_gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30)
)

myimage_face
# Out:
# array([[ 82,  59,  51,  51],
#        [157,  59,  54,  54]], dtype=int32)

# %%
for (x, y, w, h) in myimage_face:
    cv2.rectangle(myimage, (x, y), (x + w, y + h), (0, 0, 255), 2)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(myimage)
# Out:
# <PIL.Image.Image image mode=RGB size=246x198>
